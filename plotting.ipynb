# %%
import matplotlib.pyplot as plt

# %%
sparsity_levels = [0.9333333333333333, 0.9820833333333333, 0.946125, 0.9489087301587301, 0.9452380952380952]
layers = range(1, len(sparsity_levels) + 1)

plt.figure(figsize=(10, 5))
plt.plot(layers, sparsity_levels, marker='o')
plt.title('Sparsity achieved in LeNet-5 Model (Test Accuracy: 97.9%)')
plt.xlabel('Layer')
plt.ylabel('Sparsity')
plt.xticks(layers)
plt.ylim(0, 1) 

for i, sparsity in enumerate(sparsity_levels):
    plt.annotate(f'{sparsity:.4f}', (layers[i], sparsity_levels[i]), textcoords="offset points", xytext=(0,-15), ha='center')

plt.show()

# %%
test_accuracy = [0.899, 0.8994, 0.9044, 0.9028, 0.9024, 0.8966, 0.8948, 0.8932, 0.893, 0.8906, 0.8844, 0.876, 0.8806, 0.877, 0.8744, 0.8768, 0.8722, 0.8768, 0.8752, 0.8734, 0.873, 0.8702, 0.8668, 0.8632, 0.8632, 0.8726, 0.867, 0.8686, 0.863, 0.8602, 0.859, 0.8644, 0.8574, 0.8578, 0.8596]
sparsity_levels =  [0.9224537037037037, 0.921875, 0.9637586805555556, 0.890625, 0.6056043836805556, 0.90625, 0.7220594618055556, 0.890625, 0.5152180989583334, 0.703125, 0.7681206597222222, 0.421875, 0.5996839735243056, 0.3125, 0.6832275390625, 0.765625, 0.7011311848958334, 0.515625, 0.8430379231770834, 0.5234375, 0.5428432888454862, 0.20703125, 0.4292568630642361, 0.09375, 0.845550537109375, 0.94921875, 0.5096978081597222, 0.16796875, 0.6862674289279513, 0.40625, 0.6935992770724826, 0.125, 0.7161661783854166, 0.306640625, 0.860504150390625]

layers = range(1, len(sparsity_levels) + 1)

plt.figure(figsize=(10, 5))
plt.plot(layers, sparsity_levels, marker='o')
plt.title('Sparsity achieved in ResNet-18 Model (Test Accuracy: 90.01%)')
plt.xlabel('Layer')
plt.ylabel('Sparsity')
plt.xticks(layers)
plt.ylim(0, 1) 

plt.show()

# %%
# 2 iter
sparsity_levels = [0.6620370370370371, 0.890625, 0.8818359375, 0.875, 0.7851833767361112, 0.8125, 0.7252332899305556, 0.828125, 0.7315809461805556, 0.796875, 0.6803927951388888, 0.671875, 0.7013821072048612, 0.4921875, 0.9376220703125, 0.9609375, 0.80828857421875, 0.8046875, 0.9176567925347222, 0.9375, 0.5892571343315972, 0.1796875, 0.6328447129991319, 0.1015625, 0.99871826171875, 1.0, 0.5971018473307291, 0.265625, 0.7189229329427084, 0.41015625, 0.7567113240559896, 0.17578125, 0.8343476189507378, 0.298828125, 0.998748779296875, 1.0, 0.9281048244900174, 0.68359375, 0.7392828199598525, 0.818359375, 0.0984375]
layers = range(1, len(sparsity_levels) + 1)

plt.figure(figsize=(10, 5))
plt.plot(layers, sparsity_levels, marker='o')
plt.title('Sparsity achieved in ResNet-18 Model with two iterations (Test Accuracy: 89.62%)')
plt.xlabel('Layer')
plt.ylabel('Sparsity')
plt.xticks(layers)  
plt.ylim(0, 1)  
plt.show()

# %%
layers = [1, 2, 3, 4, 5]
sparsity_levels = [0.0022688231290312125, 0.040466081094220986, 0.7764398923929602, 0.9314491297442712, 0.9443165980617768]
test_accuracy = [0.9842, 0.9804, 0.9764, 0.973, 0.9616]

fig, ax1 = plt.subplots(figsize=(10, 5))

color = 'tab:blue'
ax1.set_xlabel('Number of layers pruned')
ax1.set_ylabel('Sparsity', color=color)
line1, = ax1.plot(layers, sparsity_levels, marker='o', linestyle='-', color=color, label='Sparsity')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 1) 
ax1.set_xticks(layers) 

text_pos = [(0, 10), (-10, 10), (0, 10), (0, 7), (0, 7)]
for i, txt in enumerate(sparsity_levels):
    ax1.annotate(f'{txt:.4f}', (layers[i], sparsity_levels[i]), textcoords="offset points", xytext=text_pos[i], ha='center', color=color)

ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Accuracy', color=color)
line2, = ax2.plot(layers, test_accuracy, marker='o', linestyle='-', color=color, label='Test Accuracy')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0.8, 1) 

text_pos = [(0, 10), (0, 10), (0, 10), (0, -15), (0, -15)]
for i, txt in enumerate(test_accuracy):
    ax2.annotate(f'{txt:.4f}', (layers[i], test_accuracy[i]), textcoords="offset points", xytext=text_pos[i], ha='center', color=color)

plt.title('Pruning all layers in LeNet-5')
fig.tight_layout()

plt.show()

# %%
sparsity_levels = [0.00014265307148887744, 0.000147933203996935, 0.003327467911560823, 0.0033325690565262347, 0.005330517501312426, 0.00533570814004916, 0.007717853345125033, \
                   0.0077229544900904445, 0.009422709688828367, 0.009426736908537903, 0.014494948166102587, 0.01449978082975403, 0.022413446546533808, 0.02241702629738673, \
                    0.022917922935481613, 0.02292669332507127, 0.03217909636707195, 0.032185002955979265, 0.04331006316291392, 0.043316059245592564, 0.05764320659046451, \
                        0.05764794976034463, 0.08030651974653216, 0.08030866759704391, 0.08278827151909054, 0.08281001850552204, 0.10971470996590109, 0.10971855819806797, \
                            0.14594357847288186, 0.14595288582509947, 0.21917695800289996, 0.21918268560426463, 0.3703956573326453, 0.37040970785474303, 0.38050353133472264, \
                                0.3805486361954694, 0.5448763831486092, 0.5449073479934871, 0.7464703209121348, 0.7464740796505304, 0.746518558054878]
layers = list(range(1, len(sparsity_levels)+1))
test_accuracy = [0.899, 0.8994, 0.9044, 0.9028, 0.9024, 0.8966, 0.8948, 0.8932, 0.893, 0.8906, 0.8844, 0.876, 0.8806, 0.877, 0.8744, 0.8768, 0.8722, 0.8768, 0.8752, 0.8734, 0.873, \
                 0.8702, 0.8668, 0.8632, 0.8632, 0.8726, 0.867, 0.8686, 0.863, 0.8602, 0.859, 0.8644, 0.8574, 0.8578, 0.8596, 0.863, 0.8668, 0.8686, 0.853, 0.8608, 0.8664]

fig, ax1 = plt.subplots(figsize=(10, 5))

color = 'tab:blue'
ax1.set_xlabel('Number of layers pruned')
ax1.set_ylabel('Sparsity', color=color)
line1, = ax1.plot(layers, sparsity_levels, marker='o', linestyle='-', color=color, label='Sparsity')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 1) 
ax1.set_xticks(layers) 

ax2 = ax1.twinx()  
color = 'tab:red'
ax2.set_ylabel('Accuracy', color=color)
line2, = ax2.plot(layers, test_accuracy, marker='o', linestyle='-', color=color, label='Test Accuracy')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 1)  

plt.title('Pruning all layers in ResNet-18')
fig.tight_layout()

plt.show()

# %%
sparsity_levels = [0.00010238087439352309, 0.00010748201935893463, 0.0030167455375273338, 0.003021757188721422, 0.005612154399665938, 0.005616808075774734, 0.008009424052095399, \
                   0.008014167221975517, 0.010427724740785765, 0.010432288923123239, 0.014921654467770698, 0.014929350932104476, 0.024185065243644107, 0.024190703351237457, \
                    0.024878105008769493, 0.024889112742642223, 0.03555560686531778, 0.03556482472376405, 0.047674584896565786, 0.04768532414912455, 0.06323746223586585, \
                        0.0632415789493467, 0.09664665048977256, 0.09664897732782696, 0.09957775048814378, 0.09960066089360246, 0.13111902474699663, 0.1311251103234466, \
                            0.169073870127713, 0.1690832669737019, 0.24897015042650048, 0.24897820486591954, 0.4251442773834384, 0.4251579699304508, 0.43687342054680334, \
                                0.43691924135772076, 0.6328814255856606, 0.6329127484056237, 0.7890066209281901, 0.7890441188183743, 0.7890892236791212]
layers = list(range(1, len(sparsity_levels)+1))
test_accuracy = [0.8706, 0.8842, 0.8772, 0.8762, 0.878, 0.8734, 0.8736, 0.8742, 0.8802, 0.879, 0.8746, 0.8738, 0.8702, 0.867, 0.872, 0.8698, 0.8676, 0.8606, 0.8628, 0.8664, 0.8684, \
                 0.8698, 0.8638, 0.8668, 0.8652, 0.8684, 0.8684, 0.866, 0.8708, 0.8704, 0.8662, 0.8662, 0.868, 0.8668, 0.8682, 0.8698, 0.8676, 0.8676, 0.8688, 0.8656, 0.8666]

fig, ax1 = plt.subplots(figsize=(10, 5))

color = 'tab:blue'
ax1.set_xlabel('Number of layers pruned')
ax1.set_ylabel('Sparsity', color=color)
line1, = ax1.plot(layers, sparsity_levels, marker='o', linestyle='-', color=color, label='Sparsity')
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_ylim(0, 1) 
ax1.set_xticks(layers) 

ax2 = ax1.twinx() 
color = 'tab:red'
ax2.set_ylabel('Accuracy', color=color)
line2, = ax2.plot(layers, test_accuracy, marker='o', linestyle='-', color=color, label='Test Accuracy')
ax2.tick_params(axis='y', labelcolor=color)
ax2.set_ylim(0, 1)  

plt.title('Pruning all layers in ResNet-18 (two iterations)')
fig.tight_layout()

plt.show()

# %%
# Constants and data
unpruned_params = 11.68  # in millions
pruned_params = [6.11, 3.50, 1.34, 3.80, 2.91, 2.52]  # in millions
accuracy_changes = [-0.55, -0.99, -2.96, -0.20, 0.27, -0.85]  # Δ Acc. %
methods = ["PY [5]", "CACP [23]", "P-SLR [18]", "PCNN [16]", "CRL-α = 30%", "CRL-α = 20%"]

# Calculate percentage of parameters pruned and display results
results = []
for method, pruned, acc_change in zip(methods, pruned_params, accuracy_changes):
    pruned_percentage = ((unpruned_params - pruned) / unpruned_params) * 100
    results.append((method, f"{pruned_percentage:.2f}%", f"{acc_change}%"))

# Print results
for result in results:
    print(f"Method: {result[0]}, Params Pruned: {result[1]}, Change in Accuracy: {result[2]}")
# Out:
# Method: PY [5], Params Pruned: 47.69%, Change in Accuracy: -0.55%
# Method: CACP [23], Params Pruned: 70.03%, Change in Accuracy: -0.99%
# Method: P-SLR [18], Params Pruned: 88.53%, Change in Accuracy: -2.96%
# Method: PCNN [16], Params Pruned: 67.47%, Change in Accuracy: -0.2%
# Method: CRL-α = 30%, Params Pruned: 75.09%, Change in Accuracy: 0.27%
# Method: CRL-α = 20%, Params Pruned: 78.42%, Change in Accuracy: -0.85%

# %%
generations = list(range(1, 21)) 
best_sparsity = [0.2285, 0.3784, 0.4710, 0.5488, 0.6152, 0.6860, 0.7411, 0.7838, 0.8229, 0.8497, 
                 0.8776, 0.8995, 0.9167, 0.9290, 0.9416, 0.9519, 0.9604, 0.9690, 0.9730, 0.9761]
test_accuracy = [0.9370, 0.9368, 0.9366, 0.9360, 0.9362, 0.9366, 0.9350, 0.9330, 0.9346, 0.9316, 
                 0.9306, 0.9288, 0.9286, 0.9206, 0.9214, 0.9188, 0.9144, 0.9086, 0.9038, 0.8982]

fig, ax1 = plt.subplots(figsize=(12, 6))

color = 'tab:blue'
ax1.set_xlabel('Generation')
ax1.set_ylabel('Sparsity', color=color)
ax1.plot(generations, best_sparsity, marker='o', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_title('Pruning module.layer4.0.conv2 layer in ResNet 18')
ax1.set_xticks(generations)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Accuracy', color=color)
ax2.plot(generations, test_accuracy, marker='o', color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.show()

print("Test accuracy recovered to 92.40% in 20 epochs")
# Out:
# Test accuracy recovered to 92.40% in 20 epochs

# %%
generations = list(range(1, 21)) 
best_sparsity = [0.2863, 0.3826, 0.4908, 0.5752, 0.6441, 0.7004, 0.7680, 0.8078, 0.8412, 0.8691, 
                 0.8852, 0.9025, 0.9221, 0.9330, 0.9377, 0.9398, 0.9504, 0.9563, 0.9590, 0.9652]
test_accuracy = [0.9398, 0.9410, 0.9406, 0.9368, 0.9354, 0.9370, 0.9314, 0.9292, 0.9274, 0.9304, 
                 0.9190, 0.9250, 0.9234, 0.9234, 0.9220, 0.9248, 0.9084, 0.9106, 0.9182, 0.9176]

fig, ax1 = plt.subplots(figsize=(12, 6))

color = 'tab:blue'
ax1.set_xlabel('Generation')
ax1.set_ylabel('Sparsity', color=color)
ax1.plot(generations, best_sparsity, marker='o', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_title('Pruning module.linear (linear) layer in ResNet-18')
ax1.set_xticks(generations)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Accuracy', color=color)
ax2.plot(generations, test_accuracy, marker='o', color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.show()

print("Test accuracy recovered to 93.52% in 20 epochs")
# Out:
# Test accuracy recovered to 93.52% in 20 epochs

# %%
generations = list(range(1, 21))
best_sparsity = [0.2696, 0.3767, 0.4863, 0.5692, 0.6429, 0.6904, 0.7388, 0.7842, 0.8175, 0.8438, 
                 0.8700, 0.8858, 0.8962, 0.9129, 0.9250, 0.9267, 0.9425, 0.9379, 0.9525, 0.9600]
test_accuracy = [0.9816, 0.9824, 0.9792, 0.9668, 0.9498, 0.9540, 0.9392, 0.9382, 0.9068, 0.8980, 
                 0.8708, 0.8894, 0.8866, 0.8652, 0.8500, 0.8562, 0.8350, 0.8654, 0.8392, 0.8322]

fig, ax1 = plt.subplots(figsize=(12, 6))

color = 'tab:blue'
ax1.set_xlabel('Generation')
ax1.set_ylabel('Sparsity', color=color)
ax1.plot(generations, best_sparsity, marker='o', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_title('Pruning module.feature.3 (conv2D) layer in LeNet-5 model')
ax1.set_xticks(generations)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Accuracy', color=color)
ax2.plot(generations, test_accuracy, marker='o', color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.show()

print("Test accuracy recovered to 98.78% in 10 epochs")
# Out:
# Test accuracy recovered to 98.78% in 10 epochs

# %%
generations = list(range(1, 21))
best_sparsity = [0.2598, 0.3598, 0.4820, 0.5558, 0.6137, 0.6787, 0.7350, 0.7769, 0.8165, 0.8407, 
                 0.8681, 0.8884, 0.9035, 0.9144, 0.9193, 0.9311, 0.9373, 0.9452, 0.9474, 0.9491]
test_accuracy = [0.9852, 0.9838, 0.9848, 0.9812, 0.9770, 0.9762, 0.9732, 0.9652, 0.9474, 0.9486, 
                 0.9238, 0.9078, 0.8966, 0.8976, 0.8896, 0.8844, 0.8736, 0.8640, 0.8702, 0.8750]

fig, ax1 = plt.subplots(figsize=(12, 6))

color = 'tab:blue'
ax1.set_xlabel('Generation')
ax1.set_ylabel('Sparsity', color=color)
ax1.plot(generations, best_sparsity, marker='o', color=color)
ax1.tick_params(axis='y', labelcolor=color)
ax1.set_title('Pruning module.classifier.1 (linear) layer in LeNet-5 model')
ax1.set_xticks(generations)

ax2 = ax1.twinx()
color = 'tab:red'
ax2.set_ylabel('Accuracy', color=color)
ax2.plot(generations, test_accuracy, marker='o', color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.show()

print("Test accuracy recovered to 98.88% in 10 epochs")
# Out:
# Test accuracy recovered to 98.88% in 10 epochs
